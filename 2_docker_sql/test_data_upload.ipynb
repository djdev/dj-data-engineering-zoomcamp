# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
query = """
SELECT 1 as number;
"""

pd.read_sql(query, con=engine)
# Out:
#    number
# 0       1

# %%
query = """
SELECT *
FROM pg_catalog.pg_tables
WHERE schemaname != 'pg_catalog' AND 
    schemaname != 'information_schema';
"""

pd.read_sql(query, con=engine)
# Out:
#   schemaname             tablename tableowner tablespace  hasindexes  \
# 0     public      yellow_taxi_data       root       None        True
# 1     public                 zones       root       None        True
# 2     public  yellow_tripdata_trip       root       None       False
#
#    hasrules  hastriggers  rowsecurity
# 0     False        False        False
# 1     False        False        False
# 2     False        False        False

# %%
df = pd.read_csv('yellow_tripdata_2021-01.csv', low_memory=False)

# %%
df.head(n=100)
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0        1.0  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1        1.0  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2        1.0  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3        1.0  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4        2.0  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
# ..       ...                  ...                   ...              ...
# 95       2.0  2021-01-01 00:12:41   2021-01-01 00:26:47              1.0
# 96       2.0  2021-01-01 00:23:29   2021-01-01 00:35:03              2.0
# 97       2.0  2021-01-01 00:46:17   2021-01-01 00:54:25              2.0
# 98       2.0  2021-01-01 00:28:16   2021-01-01 00:51:44              1.0
# 99       2.0  2021-01-01 00:42:35   2021-01-01 00:54:41              3.0
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            2.10         1.0                  N           142            43
# 1            0.20         1.0                  N           238           151
# 2           14.70         1.0                  N           132           165
# 3           10.60         1.0                  N           138           132
# 4            4.94         1.0                  N            68            33
# ..            ...         ...                ...           ...           ...
# 95           4.13         1.0                  N           161           226
# 96           4.12         1.0                  N           162            74
# 97           2.22         1.0                  N           144           170
# 98           7.11         1.0                  N           264           264
# 99           1.61         1.0                  N           229           237
#
#     payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0            2.0          8.0    3.0      0.5        0.00           0.0
# 1            2.0          3.0    0.5      0.5        0.00           0.0
# 2            1.0         42.0    0.5      0.5        8.65           0.0
# 3            1.0         29.0    0.5      0.5        6.05           0.0
# 4            1.0         16.5    0.5      0.5        4.06           0.0
# ..           ...          ...    ...      ...         ...           ...
# 95           1.0         14.5    0.5      0.5        3.66           0.0
# 96           2.0         13.5    0.5      0.5        0.00           0.0
# 97           1.0          9.0    0.5      0.5        2.56           0.0
# 98           2.0         23.5    0.5      0.5        0.00           0.0
# 99           2.0          9.5    0.5      0.5        0.00           0.0
#
#     improvement_surcharge  total_amount  congestion_surcharge
# 0                     0.3         11.80                   2.5
# 1                     0.3          4.30                   0.0
# 2                     0.3         51.95                   0.0
# 3                     0.3         36.35                   0.0
# 4                     0.3         24.36                   2.5
# ..                    ...           ...                   ...
# 95                    0.3         21.96                   2.5
# 96                    0.3         17.30                   2.5
# 97                    0.3         15.36                   2.5
# 98                    0.3         24.80                   0.0
# 99                    0.3         13.30                   2.5
#
# [100 rows x 18 columns]

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df.to_sql(name='yellow_tripdata_trip', con=engine, index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.to_sql(name='yellow_tripdata_trip', con=engine, index=False)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/generic.py:3008, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2813 """
#    2814 Write records stored in a DataFrame to a SQL database.
#    2815
#    (...)
#    3004 [(1,), (None,), (2,)]
#    3005 """  # noqa: E501
#    3006 from pandas.io import sql
# -> 3008 return sql.to_sql(
#    3009     self,
#    3010     name,
#    3011     con,
#    3012     schema=schema,
#    3013     if_exists=if_exists,
#    3014     index=index,
#    3015     index_label=index_label,
#    3016     chunksize=chunksize,
#    3017     dtype=dtype,
#    3018     method=method,
#    3019 )
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/sql.py:788, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     783     raise NotImplementedError(
#     784         "'frame' argument should be either a Series or a DataFrame"
#     785     )
#     787 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 788     return pandas_sql.to_sql(
#     789         frame,
#     790         name,
#     791         if_exists=if_exists,
#     792         index=index,
#     793         index_label=index_label,
#     794         schema=schema,
#     795         chunksize=chunksize,
#     796         dtype=dtype,
#     797         method=method,
#     798         engine=engine,
#     799         **engine_kwargs,
#     800     )
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/sql.py:1948, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1898 """
#    1899 Write records stored in a DataFrame to a SQL database.
#    1900
#    (...)
#    1944     Any additional kwargs are passed to the engine.
#    1945 """
#    1946 sql_engine = get_engine(engine)
# -> 1948 table = self.prep_table(
#    1949     frame=frame,
#    1950     name=name,
#    1951     if_exists=if_exists,
#    1952     index=index,
#    1953     index_label=index_label,
#    1954     schema=schema,
#    1955     dtype=dtype,
#    1956 )
#    1958 total_inserted = sql_engine.insert_records(
#    1959     table=table,
#    1960     con=self.con,
#    (...)
#    1967     **engine_kwargs,
#    1968 )
#    1970 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/sql.py:1852, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1840             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1842 table = SQLTable(
#    1843     name,
#    1844     self,
#    (...)
#    1850     dtype=dtype,
#    1851 )
# -> 1852 table.create()
#    1853 return table
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/sql.py:927, in SQLTable.create(self)
#     925 if self.exists():
#     926     if self.if_exists == "fail":
# --> 927         raise ValueError(f"Table '{self.name}' already exists.")
#     928     if self.if_exists == "replace":
#     929         self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'yellow_tripdata_trip' already exists.

# %%
query = """
SELECT * FROM yellow_tripdata_trip ORDER BY tpep_pickup_datetime ASC
"""

pd.read_sql(query, con=engine)
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2021-01-01 00:00:28   2021-01-01 00:17:28                1
# 1          2  2021-01-01 00:03:09   2021-01-01 00:15:45                1
# 2          1  2021-01-01 00:03:13   2021-01-01 00:03:19                1
# 3          2  2021-01-01 00:03:48   2021-01-01 00:14:29                1
# 4          2  2021-01-01 00:04:21   2021-01-01 00:07:58                1
# ..       ...                  ...                   ...              ...
# 95         2  2021-01-01 00:55:13   2021-01-01 01:23:03                1
# 96         2  2021-01-01 00:55:19   2021-01-01 00:58:45                2
# 97         2  2021-01-01 00:56:22   2021-01-01 01:00:09                1
# 98         2  2021-01-01 00:56:30   2021-01-01 01:02:03                2
# 99         2  2021-01-01 00:57:26   2021-01-01 01:01:27                1
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            4.10           1                  N            95           157
# 1            4.85           1                  N           137           256
# 2            0.00           1                  N           169           169
# 3            1.98           1                  N           100           229
# 4            0.78           1                  N           239           238
# ..            ...         ...                ...           ...           ...
# 95          13.67           1                  N            48            32
# 96           1.05           1                  N           263            75
# 97           1.17           1                  N           263           141
# 98           1.16           1                  N           238           142
# 99           0.89           1                  N           142            48
#
#     payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0              2         16.0    0.5      0.5        0.00           0.0
# 1              1         16.5    0.5      0.5        4.06           0.0
# 2              3          0.0    0.0      0.0        0.00           0.0
# 3              2          9.5    0.5      0.5        0.00           0.0
# 4              1          4.5    0.5      0.5        1.66           0.0
# ..           ...          ...    ...      ...         ...           ...
# 95             2         38.0    0.5      0.5        0.00           0.0
# 96             1          5.5    0.5      0.5        1.86           0.0
# 97             1          5.5    0.5      0.5        1.86           0.0
# 98             1          6.5    0.5      0.5        1.54           0.0
# 99             2          5.0    0.5      0.5        0.00           0.0
#
#     improvement_surcharge  total_amount  congestion_surcharge
# 0                     0.3         17.30                   0.0
# 1                     0.3         24.36                   2.5
# 2                     0.0          0.00                   0.0
# 3                     0.3         13.30                   2.5
# 4                     0.3          9.96                   2.5
# ..                    ...           ...                   ...
# 95                    0.3         41.80                   2.5
# 96                    0.3         11.16                   2.5
# 97                    0.3         11.16                   2.5
# 98                    0.3         11.84                   2.5
# 99                    0.3          8.80                   2.5
#
# [100 rows x 18 columns]

# %%
query = """
SELECT * FROM pg_catalog.pg_tables
WHERE schemaname != 'pg_catalog' AND 
    schemaname != 'information_schema';"""

pd.read_sql(query, con=engine)
# Out:
#   schemaname             tablename tableowner tablespace  hasindexes  \
# 0     public      yellow_taxi_data       root       None        True
# 1     public                 zones       root       None        True
# 2     public  yellow_tripdata_trip       root       None       False
#
#    hasrules  hastriggers  rowsecurity
# 0     False        False        False
# 1     False        False        False
# 2     False        False        False

# %%
query = """
SELECT * FROM yellow_tripdata_trip WHERE tip_amount='12.25'
"""

pd.read_sql(query, con=engine)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:22:52   2021-01-01 00:43:49                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           17.2           2                  N           132           107
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         52.0    2.5      0.5       12.25          6.12
#
#    improvement_surcharge  total_amount  congestion_surcharge
# 0                    0.3         73.67                   2.5
